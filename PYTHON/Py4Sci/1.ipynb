# %%
import pandas as pd
import numpy as np

# %%
m=np.random.randint(2,100)
n=np.random.randint(2,100)
index=["分销商"+str(i+1) for i in range(n)]+["商品存量"]
columns=["商品"+str(i+1) for i in range(m)]+["分销上限"]
df=pd.DataFrame(index=index,columns=columns)
df.head
# Out:
# <bound method NDFrame.head of        商品1  商品2  商品3  商品4  商品5  商品6  商品7  商品8  商品9 商品10  ... 商品77 商品78 商品79  \
# 分销商1   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 分销商2   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 分销商3   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 分销商4   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 分销商5   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 分销商59  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 分销商60  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 分销商61  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 分销商62  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 商品存量   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
# ...

# %%
U=np.random.randint(200,1000,size=n)
C=np.random.randint(0,500,size=(n,m))
V=np.random.randint(500,1000,size=m)

df.iloc[n,0:m]=V
df.iloc[0:n,m]=U
df.iloc[0:n,0:m]=C

# %%
print(n,m)
print(df.head)
df.info()
# Out:
# 62 85
# <bound method NDFrame.head of        商品1  商品2  商品3  商品4  商品5  商品6  商品7  商品8  商品9 商品10  ... 商品77 商品78 商品79  \
# 分销商1   240  361  198  263  352  225  103  389  144  273  ...  477  433  158
# 分销商2   349  238   54  142  441  480  457  402  447   49  ...  426  337  166
# 分销商3   314  399  283  389  103  144   94  153  390  303  ...  413  193  412
# 分销商4   488  372  438  454  281  270  224  314  445  482  ...  408   68  459
# 分销商5   357  372   90  466  341   41  236   33  407  230  ...  258  305   66
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 分销商59  492  173  239  315  131  429    3  209  309  299  ...   33  352  232
# 分销商60  306   34  348   89  434  361  208  444  486  478  ...   79  247  384
# 分销商61   89  492    3    3   74  299  294   23  109  390  ...  268  247  144
# 分销商62  155  295   96  190  371  482  300  148  394   31  ...   38  372  264
# 商品存量   683  554  567  577  671  867  621  841  894  823  ...  893  574  821
#
# ...

# %%
df.to_csv('list.csv')
